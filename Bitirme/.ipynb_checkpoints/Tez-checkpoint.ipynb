# %%
place_name = "Erciyes Universitesi,Kayseri,Türkiye"

# %% [markdown]
# ## KÜTÜPHANELER

# %%
import osmnx as ox
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt

# %%
area = ox.geocode_to_gdf("Erciyes Universitesi,Kayseri,Türkiye")

# %%
area.head()
# Out:
#                                             geometry  bbox_north  bbox_south
# 0  POLYGON ((35.51532 38.70391, 35.51671 38.70319...   38.719179   38.696428  \
#
#    bbox_east  bbox_west   place_id osm_type     osm_id        lat        lon
# 0    35.5517  35.515318  171881182      way  254566790  38.707391  35.533757  \
#
#                                         display_name    class        type
# 0  Erciyes University, Özyurt 1.Sokağı, Köşk Maha...  amenity  university  \
#
#    importance
# 0    0.601205

# %% [markdown]
# ## Erciyes Universitesi

# %%
area.plot()
# Out:
# <Axes: >

# %%
# CRS'yi projeksiyonlu bir CRS'ye dönüştürme
area_proj = area.to_crs("EPSG:3857")

# Alan hesaplamasını projeksiyonlu geometri üzerinde yapma
total_area = area_proj.geometry.area.sum()

# Alanı yazdır
print("Erciyes Üniversitesi Alanı:", total_area, "metrekare")
# Out:
# Erciyes Üniversitesi Alanı: 5952697.007307933 metrekare

# %% [markdown]
# ## Erciyes Universitesi Binalar

# %%
tags = {'building': True}   

buildings = ox.geometries_from_place('Erciyes Universitesi,Kayseri,Türkiye', tags)
buildings.head()
# Out:
#                            building                           source
# element_type osmid
# node         2613374526  university                             bing  \
# way          254642917   university  Maxar Premium-Luftbilder (Beta)
#              254643086   university                             bing
#              254649971   university                             bing
#              254653739   university                             bing
#
#                                                                   geometry
# element_type osmid
# node         2613374526                          POINT (35.53729 38.71103)  \
# way          254642917   POLYGON ((35.53979 38.71077, 35.54001 38.71071...
#              254643086   POLYGON ((35.53906 38.71091, 35.53946 38.71081...
#              254649971   POLYGON ((35.53374 38.70747, 35.53417 38.70762...
#              254653739   POLYGON ((35.52201 38.70791, 35.52225 38.70778...
#
#                                                                      nodes
# element_type osmid
# node         2613374526                                                NaN  \
# way          254642917   [2604505912, 2604505913, 4156165060, 415616505...
#              254643086   [2604507552, 2604507553, 2604507554, 260450755...
#              254649971   [2604565930, 2604565933, 2604565935, 260456593...
#              254653739   [2604600140, 2604600139, 2604600137, 260460013...
#
#                                                             name addr:city
# element_type osmid
# node         2613374526                                      NaN       NaN  \
# way          254642917   Mustafa Çıkrıkçıoğlu Meslek Yüksekokulu       NaN
#              254643086            Güzel Sanatlar Fak.Heykel Böl.   Kayseri
#              254649971    Personel ve Öğrenci Merkez Yemekhanesi       NaN
#              254653739                                    Kosgeb       NaN
#
#                         addr:country leisure amenity healthcare  ... email
# element_type osmid                                               ...
# node         2613374526          NaN     NaN     NaN        NaN  ...   NaN  \
# way          254642917           NaN     NaN     NaN        NaN  ...   NaN
#              254643086            TR     NaN     NaN        NaN  ...   NaN
#              254649971           NaN     NaN     NaN        NaN  ...   NaN
#              254653739           NaN     NaN     NaN        NaN  ...   NaN
#
#                         tourism website ways type description alt_name
# element_type osmid
# node         2613374526     NaN     NaN  NaN  NaN         NaN      NaN  \
# way          254642917      NaN     NaN  NaN  NaN         NaN      NaN
#              254643086      NaN     NaN  NaN  NaN         NaN      NaN
#              254649971      NaN     NaN  NaN  NaN         NaN      NaN
#              254653739      NaN     NaN  NaN  NaN         NaN      NaN
#
#                         religion emergency alt_name:en
# element_type osmid
# node         2613374526      NaN       NaN         NaN
# way          254642917       NaN       NaN         NaN
#              254643086       NaN       NaN         NaN
#              254649971       NaN       NaN         NaN
#              254653739       NaN       NaN         NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# Erciyes Üniversitesi Bina Sayısı

# %%
# Erciyes Üniversitesi binalarının sayısı
building_count = buildings.shape[0]
print("Erciyes Üniversitesi Bina Sayısı:", building_count)
# Out:
# Erciyes Üniversitesi Bina Sayısı: 187

# %%
building_names = buildings['name']
building_names.dropna(inplace=True)

for i, name in enumerate(building_names):
    print('Bina', i+1, ':', name)
# Out:
# Bina 1 : Mustafa Çıkrıkçıoğlu Meslek Yüksekokulu
# Bina 2 : Güzel Sanatlar Fak.Heykel Böl.
# Bina 3 : Personel ve Öğrenci Merkez Yemekhanesi
# Bina 4 : Kosgeb
# Bina 5 : Mobilya Atölyesi
# Bina 6 : Öğrenci Yemekhanesi
# Bina 7 : Fehmi Özilhan Sivil Havacılık Yüksekokulu
# Bina 8 : İlahiyat Fakültesi
# Bina 9 : İlahiyat Fakültesi Kantin-kafe
# Bina 10 : İlahiyat Fakültesi
# Bina 11 : İlahiyat Fakültesi
# Bina 12 : Lojman
# Bina 13 : Erciyes Üniversitesi Rektörlük
# Bina 14 : Spor Salonu
# Bina 15 : Spor Salonu
# Bina 16 : Türkan-Tuncer Hasçalık Turizm İşletmeciliği ve Otelcilik Yüksekokulu
# Bina 17 : Adalet Yüksekokulu ve Hukuk Fakültesi
# Bina 18 : Eğitim Fakültesi
# Bina 19 : UZAYBİMER
# Bina 20 : Sürekli Eğitim Merkezi - Ersem
# Bina 21 : Lojman
# Bina 22 : Lojman
# Bina 23 : Lojman
# Bina 24 : Lojman
# Bina 25 : Mustafa Kılıçer Eczacılık Fakültesi
# Bina 26 : Lojman
# Bina 27 : Lojman
# Bina 28 : Süleyman Çetinsaya Iletişim Fakültesi
# Bina 29 : Güzel Sanatlar fak.Müzik Böl.
# Bina 30 : Öğrenci Kantini ve konferans salonu
# Bina 31 : Betül - Ziya Eren Genetik ve Kök Hücre Araştırma Merkezi
# Bina 32 : Tıp Fakültesi Derslikleri
# Bina 33 : Hülya Mehmet Tatar Diş Hekimliği Fakültesi
# Bina 34 : Gülşah Mehmet Tatar Diş Hekimliği Fakültesi
# Bina 35 : Sağlık Bilimleri Fakültesi
# Bina 36 : Bilgi İşlem Daire Başkanlığı
# Bina 37 : Kalp ve Onkoloji Hastanesi
# Bina 38 : Sabancı Kültür Sitesi
# Bina 39 : Erciyes Üniversitesi Merkez Lojmanları 4. Blok
# Bina 40 : Erciyes Üniversitesi Merkez Lojmanları 1. Blok
# Bina 41 : Erciyes Üniversitesi Merkez Lojmanları 3. Blok
# Bina 42 : Erciyes Üniversitesi Merkez Lojmanları 2. Blok
# Bina 43 : Kalp ve Onkoloji Hastanesi
# Bina 44 : Organ Nakli ve Diyaliz Hastanesi
# Bina 45 : Çocuk Hastanesi
# Bina 46 : Halil Bayraktar Sağlık Hizmetleri Yüksekokulu
# Bina 47 : Hastane Yemekhanesi
# Bina 48 : Klinik Mühendisliği
# Bina 49 : Kreş
# Bina 50 : Bankalar
# Bina 51 : Enerji Dağıtım Merkezi
# Bina 52 : Lab
# Bina 53 : Erkam
# Bina 54 : Dekam
# Bina 55 : Havuz
# Bina 56 : Safiye Çıkrıkçıoğlu Yüksekokulu
# Bina 57 : Şenlik Alanı
# Bina 58 : KYK Erciyes Erkek yurdu A blok
# Bina 59 : KYK Erciyes Erkek yurdu C blok
# Bina 60 : KYK Erciyes Erkek yurdu B blok
# Bina 61 : Bilim Sitesi
# Bina 62 : Hızıroğlu Konağı
# Bina 63 : Bilim Sitesi
# Bina 64 : Türk Kızılayı
# Bina 65 : Çardak Öğrenci Kantini,kafe
# Bina 66 : Park Bahçe Işl. Müdürlüğü
# Bina 67 : Park Bahçe Işl. Müdürlüğü
# Bina 68 : Kızılay Misafirhanesi
# Bina 69 : Giriş
# Bina 70 : uçak  heykeli
# Bina 71 : Türk Kızılayı
# Bina 72 : Beden Eğitimi ve Spor Yüksekokulu
# Bina 73 : Spor Salonu
# Bina 74 : Makina Mühendisleri Laboratuvarı
# Bina 75 : Makina Mühendisleri Laboratuvarı
# Bina 76 : Çadır Kafe,öğrenci kantini
# Bina 77 : Mühendislik Fak. Kantin-Kafe
# Bina 78 : Fevzi Mercan Nano Teknoloji Araştırma Merkezi
# Bina 79 : Yemekhane
# Bina 80 : KYK Erciyes Erkek yurdu D blok
# Bina 81 : Erciyes Kültür Merkezi
# Bina 82 : ESKİ Fen Fakültesi - Edebiyat Fakültesi
# Bina 83 : Öğrenci İşleri ve Mediko Sosyal Merkezi
# Bina 84 : Sağlık Bilimleri Fakültesi
# Bina 85 : Sosyal Güvenlik Kurumu
# Bina 86 : Personel Yemekhanesi
# Bina 87 : Çocuk Hematoloji-Onkoloji ve Kemik İliği Nakli Hastanesi
# Bina 88 : Erciyes University Pond Cafe
# Bina 89 : The Emar Otel Deluxe
# Bina 90 : İzzet Bayraktar Sosyal Bilimler Meslek Yüksekokulu
# Bina 91 : Mimarlık Fakültesi
# Bina 92 : Mühendislik Fakültesi
# Bina 93 : Fakülte Cami
# Bina 94 : Güzel Sanatlar Fakültesi Resim Bölümpü
# Bina 95 : Enstitüler Binası
# Bina 96 : Süleyman Demirel Kapalı Spor Salonu
# Bina 97 : Dr. Sait Molu Acil Servisi
# Bina 98 : Tıp Fakültesi Dekanlığı
# Bina 99 : Göğüs Hastanesi
# Bina 100 : İktisadi ve İdari Bilimler Fakültesi
# Bina 101 : Gevher Nesibe Hastanesi
# Bina 102 : Veteriner Fakültesi
# Bina 103 : Kayseri Meslek Yüksekokulu
# Bina 104 : Fen - Edebiyat Fakültesi
# Bina 105 : Tıbbı Atık Tesisi

# %%
buildings.plot()
# Out:
# <Axes: >

# %%
if not buildings.empty:
    # CRS'yi projeksiyonlu bir CRS'ye dönüştürme
    buildings_proj = buildings.to_crs("EPSG:3857")

    # Alan hesaplamasını projeksiyonlu geometri üzerinde yapma
    total_areas = buildings_proj.geometry.area.sum()

    print("Toplam Bina Alanı:", total_areas, "metrekare")
# Out:
# Toplam Bina Alanı: 411997.55832270824 metrekare

# %% [markdown]
# ## Erciyes Universitesi Yollar

# %%
tags = {'highway': True}
place = "Erciyes Universitesi, Kayseri, Türkiye"
roads = ox.geometries_from_place(place, tags)
roads.head()
# Out:
#                           highway                          name
# element_type osmid
# node         7963544775  bus_stop  Sosyal Güvenlik Kurumu Önü 3  \
#              7963566825  bus_stop                   Lojmanlar 5
#              7963580398  bus_stop                   Kız Yurdu 1
#              7963587825  bus_stop             İlahiyat Girişi 9
#              7963592591  bus_stop       Şehit Komandolar Durağı
#
#                                                   source
# element_type osmid
# node         7963544775  Maxar Premium-Luftbilder (Beta)  \
#              7963566825  Maxar Premium-Luftbilder (Beta)
#              7963580398  Maxar Premium-Luftbilder (Beta)
#              7963587825  Maxar Premium-Luftbilder (Beta)
#              7963592591  Maxar Premium-Luftbilder (Beta)
#
#                                           geometry alt_name  bus
# element_type osmid
# node         7963544775  POINT (35.53137 38.69835)      NaN  yes  \
#              7963566825  POINT (35.52758 38.69947)      NaN  yes
#              7963580398  POINT (35.53713 38.69665)      NaN  yes
#              7963587825  POINT (35.51792 38.70265)      NaN  yes
#              7963592591  POINT (35.52214 38.70104)      NaN  yes
#
#                                      network                       operator
# element_type osmid
# node         7963544775  Kayseri Ulaşım A.Ş.  Kayseri Büyükşehir Belediyesi  \
#              7963566825  Kayseri Ulaşım A.Ş.  Kayseri Büyükşehir Belediyesi
#              7963580398  Kayseri Ulaşım A.Ş.  Kayseri Büyükşehir Belediyesi
#              7963587825  Kayseri Ulaşım A.Ş.  Kayseri Büyükşehir Belediyesi
#              7963592591  Kayseri Ulaşım A.Ş.  Kayseri Büyükşehir Belediyesi
#
#                         public_transport   ref  ... bridge layer tunnel
# element_type osmid                              ...
# node         7963544775         platform  1464  ...    NaN   NaN    NaN  \
#              7963566825         platform  1244  ...    NaN   NaN    NaN
#              7963580398         platform  1587  ...    NaN   NaN    NaN
#              7963587825         platform   806  ...    NaN   NaN    NaN
#              7963592591         platform  1007  ...    NaN   NaN    NaN
#
#                         junction lane_markings handrail footway ramp
# element_type osmid
# node         7963544775      NaN           NaN      NaN     NaN  NaN  \
#              7963566825      NaN           NaN      NaN     NaN  NaN
#              7963580398      NaN           NaN      NaN     NaN  NaN
#              7963587825      NaN           NaN      NaN     NaN  NaN
#              7963592591      NaN           NaN      NaN     NaN  NaN
#
#                         ramp:wheelchair tactile_paving
# element_type osmid
# node         7963544775             NaN            NaN
#              7963566825             NaN            NaN
#              7963580398             NaN            NaN
#              7963587825             NaN            NaN
#              7963592591             NaN            NaN
#
# [5 rows x 28 columns]

# %%
roads.plot()
# Out:
# <Axes: >

# %% [markdown]
# Erciyes Üniversitesi Yollarının Uzunluğu

# %%
roads = ox.geometries_from_place(place, tags)
roads_proj = roads.to_crs("EPSG:3857")

road_length = roads_proj.geometry.length.sum()
print("Erciyes Üniversitesi Yol Uzunluğu:", road_length, "metre")
# Out:
# Erciyes Üniversitesi Yol Uzunluğu: 82956.83388606689 metre

# %% [markdown]
# ## OTOPARKLAR

# %%
place = "Erciyes Universitesi, Kayseri, Türkiye"
tags = {"amenity": "parking"}
parking = ox.geometries_from_place(place, tags)
parking.head()
# Out:
#                                                                     nodes
# element_type osmid
# way          255660630  [2613313692, 2613313684, 2613313757, 261331378...  \
#              255660632  [2613313680, 2613313679, 2613313703, 261331374...
#              255666813  [2613374129, 2613374147, 2613374218, 261337421...
#              255669782  [2613412099, 2613412115, 2613412181, 261341218...
#              255669789  [2613412075, 2613412081, 2613412091, 261341209...
#
#                         amenity source
# element_type osmid
# way          255660630  parking   bing  \
#              255660632  parking   bing
#              255666813  parking   bing
#              255669782  parking   bing
#              255669789  parking   bing
#
#                                                                  geometry
# element_type osmid
# way          255660630  POLYGON ((35.53821 38.71009, 35.53860 38.70999...  \
#              255660632  POLYGON ((35.53679 38.70981, 35.53724 38.70969...
#              255666813  POLYGON ((35.53872 38.70469, 35.53910 38.70479...
#              255669782  POLYGON ((35.53917 38.70914, 35.53933 38.70916...
#              255669789  POLYGON ((35.53857 38.70835, 35.53894 38.70841...
#
#                        name access parking  fee capacity:disabled surface
# element_type osmid
# way          255660630  NaN    NaN     NaN  NaN               NaN     NaN  \
#              255660632  NaN    NaN     NaN  NaN               NaN     NaN
#              255666813  NaN    NaN     NaN  NaN               NaN     NaN
#              255669782  NaN    NaN     NaN  NaN               NaN     NaN
#              255669789  NaN    NaN     NaN  NaN               NaN     NaN
#
#                        ways type
# element_type osmid
# way          255660630  NaN  NaN
#              255660632  NaN  NaN
#              255666813  NaN  NaN
#              255669782  NaN  NaN
#              255669789  NaN  NaN

# %%
parking.plot()
# Out:
# <Axes: >

# %% [markdown]
# Erciyes Üniversitesi Otopark Sayısı

# %%
parking_count = parking_areas.shape[0]
print("Erciyes Üniversitesi Otopark Sayısı:", parking_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 parking_count = parking_areas.shape[0]
#       2 print("Erciyes Üniversitesi Otopark Sayısı:", parking_count)
#
# NameError: name 'parking_areas' is not defined

# %%
# Overpass API'ye sorgu gönderin
response_json = ox.geometries_from_place(place, tags=tags)

# GeoDataFrame'i oluşturun
parking_areas = gpd.GeoDataFrame.from_features(response_json)

# CRS'yi belirtin
parking_areas.crs = "EPSG:4326"

if not parking_areas.empty:
    # CRS'yi projeksiyonlu bir CRS'ye dönüştürme
    parking_areas_proj = parking_areas.to_crs("EPSG:3857")

    # Alan hesaplamasını projeksiyonlu geometri üzerinde yapma
    total_area = parking_areas_proj.geometry.area.sum()

    print("Otopark Alanı:", total_area, "metrekare")
# Out:
# Otopark Alanı: 155327.59263737453 metrekare

# %% [markdown]
# ## Erciyes Üniversitesi Yeşil Alanlar

# %% [markdown]
# Yeşil Alan hesabı yaparken natural = scrub,landuse=meadow olaral alındı.
# Scrub= Çoğunlukla otları, otları ve geofitleri de içeren, çalıların (çalılar ve bodur ağaçlar) hakim olduğu bitki örtüsü ile karakterize edilen bir bitki topluluğudur.
# Meadow=doğal veya yapay olarak düzenlenmiş, çimlerle kaplı, düşük boylu bitkilerin ve otların yoğun olduğu açık alanlardır

# %%
# Sorgulanacak etiketleri belirle
tags = {"landuse": ["scrub", "meadow"]}

# Overpass API'ye sorgu gönder
response_json = ox.geometries_from_place(place, tags=tags)

# GeoDataFrame'i oluştur
green_areas = gpd.GeoDataFrame.from_features(response_json)
green_areas.head()
# Out:
#                                             geometry
# 0  POLYGON ((35.53699 38.70567, 35.53753 38.70581...  \
# 1  POLYGON ((35.53713 38.70486, 35.53733 38.70491...
# 2  POLYGON ((35.53809 38.70499, 35.53811 38.70500...
# 3  POLYGON ((35.53810 38.70470, 35.53813 38.70472...
# 4  POLYGON ((35.53818 38.70453, 35.53871 38.70466...
#
#                                                nodes addr:city addr:country
# 0  [2613374222, 2613374225, 2613374183, 261337417...   Kayseri           TR  \
# 1  [2613374159, 2613374176, 2613374155, 261331353...   Kayseri           TR
# 2  [2613374187, 2613374189, 2613374188, 261337418...   Kayseri           TR
# 3  [6198992943, 2613313525, 2613313523, 261331352...   Kayseri           TR
# 4  [2613374112, 2613374124, 2613374106, 261337410...   Kayseri           TR
#
#   landuse natural source  ways  type
# 0  meadow   grass   bing  None  None
# 1  meadow   grass   bing  None  None
# 2  meadow   grass   bing  None  None
# 3  meadow   grass   bing  None  None
# 4  meadow   grass   bing  None  None

# %%
green_areas.plot()
# Out:
# <Axes: >

# %% [markdown]
# Erciyes Üniversitesi Yeşil Alan Sayısı

# %%
green_area_count = green_areas.shape[0]
print("Erciyes Üniversitesi Yeşil Alan Sayısı:", green_area_count)
# Out:
# Erciyes Üniversitesi Yeşil Alan Sayısı: 137

# %%
green_areas.crs = "EPSG:4326"
if not green_areas.empty:
    # CRS'yi projeksiyonlu bir CRS'ye dönüştürme
    green_areas_proj = green_areas.to_crs("EPSG:3857")

    # Alan hesaplamasını projeksiyonlu geometri üzerinde yapma
    total_area = green_areas_proj.geometry.area.sum()

    print("Yeşil Alan:", total_area, "metrekare")
# Out:
# Yeşil Alan: 1699608.5950608621 metrekare

# %%
tags = {"natural": "water"}

# Overpass API'ye sorgu gönder
response_json = ox.geometries_from_place(place, tags=tags)

# GeoDataFrame'i oluştur
water_areas = gpd.GeoDataFrame.from_features(response_json)
water_areas.head()
# Out:
#                                             geometry
# 0  POLYGON ((35.52977 38.70127, 35.52956 38.70144...  \
#
#                                                nodes addr:city addr:country
# 0  [2614515754, 2614515769, 2614515768, 261451576...   Kayseri           TR  \
#
#   intermittent natural salt source water
# 0           no   water   no   bing  pond

# %%
water_areas.plot()
# Out:
# <Axes: >

# %% [markdown]
# Erciyes Üniversitesi göllerinin sayıs

# %%
water_area_count = water_areas.shape[0]
print("Erciyes Üniversitesi Göl Sayısı:", water_area_count)
# Out:
# Erciyes Üniversitesi Göl Sayısı: 1

# %%
water_areas.crs = "EPSG:4326"
if not water_areas.empty:
    # CRS'yi projeksiyonlu bir CRS'ye dönüştürme
    water_areas_proj = water_areas.to_crs("EPSG:3857")

    # Alan hesaplamasını projeksiyonlu geometri üzerinde yapma
    total_area = water_areas_proj.geometry.area.sum()

    print("Yeşil Alan:", total_area, "metrekare")
# Out:
# Yeşil Alan: 18697.919726802327 metrekare

# %% [markdown]
# # Kullanılan alanlar

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Kullanılan alanları çiz
area.plot(ax=ax, color='lightgray', edgecolor='black')
buildings.plot(ax=ax, color='blue', alpha=0.7)
roads.plot(ax=ax, color='gray', alpha=0.5, linewidth=1)
parking.plot(ax=ax, color='orange', alpha=0.5)
green_areas.plot(ax=ax, color='green', alpha=0.5)
water_areas.plot(ax=ax, color='cyan', alpha=0.7)

# Eksenleri kapat
ax.set_axis_off()

# Görüntüyü göster
plt.show()

# %%
# Alanı al
area = ox.geocode_to_gdf(place_name)

# Kullanılan alanlar
buildings = ox.geometries_from_place(place_name, tags={'building': True})
roads = ox.geometries_from_place(place_name, tags={'highway': True})
parking = ox.geometries_from_place(place_name, tags={'amenity': 'parking'})
green_areas = ox.geometries_from_place(place_name, tags={'landuse': ['grass', 'meadow', 'park']})
water_areas = ox.geometries_from_place(place_name, tags={'natural': 'water'})

# Kullanılan alanları çıkar
unused_area = area.difference(buildings.unary_union).difference(roads.unary_union).difference(parking.unary_union).difference(green_areas.unary_union).difference(water_areas.unary_union)

# Kullanılmayan alanı çiz
fig, ax = plt.subplots(figsize=(10, 10))
unused_area.plot(ax=ax, color='lightgray', edgecolor='black')

plt.axis('off')
plt.show()

# %%
# CRS'yi projeksiyonlu bir CRS'ye dönüştürme
unused_area_proj = unused_area.to_crs("EPSG:3857")

# Alan hesaplamasını projeksiyonlu geometri üzerinde yapma
unused_area_area = unused_area_proj.geometry.area.sum()

print("Kullanılmayan Alan:", unused_area_area, "metrekare")
# Out:
# Kullanılmayan Alan: 3864324.9362954455 metrekare
