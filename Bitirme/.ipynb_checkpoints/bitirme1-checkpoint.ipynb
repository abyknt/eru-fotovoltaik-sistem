# %%
import pandas as pd
import geopandas
import matplotlib

# %%
eruMaps = geopandas.read_file("C:/Users/ali/Desktop/shape")

# %%
eruMaps.head()
# Out:
#       osm_id                                     name        type
# 0  254642917  Mustafa Çıkrıkçıoğlu Meslek Yüksekokulu  university  \
# 1  254643086           Güzel Sanatlar Fak.Heykel Böl.  university
# 2  254649971   Personel ve Öğrenci Merkez Yemekhanesi  university
# 3  254653739                                   Kosgeb  university
# 4  254654014                         Mobilya Atölyesi  university
#
#                                             geometry
# 0  POLYGON ((35.53979 38.71077, 35.54001 38.71071...
# 1  POLYGON ((35.53906 38.71091, 35.53946 38.71081...
# 2  POLYGON ((35.53374 38.70747, 35.53417 38.70762...
# 3  POLYGON ((35.52201 38.70791, 35.52225 38.70778...
# 4  POLYGON ((35.52076 38.70834, 35.52097 38.70823...

# %%
eruMaps.geometry
# Out:
# 0      POLYGON ((35.53979 38.71077, 35.54001 38.71071...
# 1      POLYGON ((35.53906 38.71091, 35.53946 38.71081...
# 2      POLYGON ((35.53374 38.70747, 35.53417 38.70762...
# 3      POLYGON ((35.52201 38.70791, 35.52225 38.70778...
# 4      POLYGON ((35.52076 38.70834, 35.52097 38.70823...
#                              ...
# 460    POLYGON ((35.54407 38.71413, 35.54427 38.71430...
# 461    POLYGON ((35.52877 38.71451, 35.52894 38.71443...
# 462    POLYGON ((35.52822 38.70389, 35.52794 38.70341...
# 463    POLYGON ((35.52894 38.70142, 35.52910 38.70147...
# 464    POLYGON ((35.52989 38.69931, 35.52999 38.69955...
# Name: geometry, Length: 465, dtype: geometry

# %%
eruMaps.plot()
# Out:
# <Axes: >

# %%
type(eruMaps)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
eruMaps.geometry.area
# Out:
# C:\Users\ali\AppData\Local\Temp\ipykernel_11536\4093749988.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   eruMaps.geometry.area
# 0      1.804190e-07
# 1      1.369100e-07
# 2      4.118824e-07
# 3      6.394461e-08
# 4      8.266631e-08
#            ...
# 460    1.790052e-08
# 461    1.794768e-07
# 462    1.544316e-07
# 463    1.419107e-08
# 464    4.334650e-07
# Length: 465, dtype: float64

# %%
eruMaps.geometry.buffer(0.000004).plot()
# Out:
# C:\Users\ali\AppData\Local\Temp\ipykernel_11536\638839588.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   eruMaps.geometry.buffer(0.000004).plot()
# <Axes: >

# %%
eruMaps.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
eruMaps_mercator = eruMaps.to_crs(epsg=3395)

# %%
eruMaps.plot()
# Out:
# <Axes: >
